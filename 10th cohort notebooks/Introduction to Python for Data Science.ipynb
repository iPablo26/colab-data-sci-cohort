# %% [markdown]
# ## Documenting Your code

# %%
# Comments 
# Importing packages/libraries/modules for time series analysis 
import warnings # Package for creating warnings 
import itertools
import numpy as np # Package for numerical analysis
import matplotlib.pyplot as plt # Module for visualization
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
data_student = 'Deborah' # Data Science Student

# %%
print(data_student)
# Out:
# Deborah

# %%
# Commenting out
# print(data_student)

# %%
# Docstrings 
print("Hello" + " " + data_student)
# Out:
# Hello Deborah

# %%
def greetings(word):
    """
    A function for saying hello
    
    """
    print(f"Hello {word}")

# %%
greetings(data_student)
# Out:
# Hello Deborah

# %%
greetings()

# %%
# Python Style Guide aka PEP8
def multiplier(
            var_one, var_two, var_three,
            var_four):

# %% [markdown]
# ## Learning Through Articles

# %% [markdown]
# https://towardsdatascience.com/python-water-quality-eda-and-potability-analysis-ebc1cf553081

# %%
import sys
print(sys.version) # displays the version of python installed
# Out:
# 3.10.9 (main, Mar  1 2023, 12:33:47) [Clang 14.0.6 ]

# %%
# import pandas and numpy
import pandas as pd 
import numpy as np

# %%
import math
import statistics as st

# %%
list_numbers = [23, 45, 67]

# %%
st.mean(list_numbers)
# Out:
# 45

# %%
df = pd.read_csv('water_potability.csv')

# %%
df.head(20)
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         NaN  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# ...

# %%
df_potable = df[df['Potability'] == 1]

# %%
df_potable.head(20)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 250   9.445130  145.805402  13168.529156     9.444471  310.583374
# 251   9.024845  128.096691  19859.676476     8.016423  300.150377
# 252        NaN  169.974849  23403.637304     8.519730         NaN
# 253   6.800119  242.008082  39143.403329     9.501695  187.170714
# 254   7.174135  203.408935  20401.102461     7.681806  287.085679
# 255   7.657991  236.960889  14245.789121     6.289065  373.165363
# 256   8.322987  207.252462  28049.646283     8.827061  297.813085
# 257   5.934279  223.858125  23249.653834     4.602850         NaN
# 258   9.802721   98.771644  27357.456745     9.218150  323.199077
# 259   6.101955  215.268090  15976.926225     8.857160  308.482695
# 260   4.997771  280.082411  26849.194735     6.130757  374.232961
# 261   4.815767  217.687093  16392.135069     7.461170  278.742296
# 262   6.548021  278.585105  25508.386949     6.749378  366.871502
# ...
